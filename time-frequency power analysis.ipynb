# %% [markdown]
# # Code Associated with Research Question 1
#
# __Research Question 1__ <br>
# "Is there a change in the low-frequency power between _uncertain_ and _certain_ conditions?"

# %% [markdown]
# ### 1. Compute Time-frequency Representation
#
# - outliers are not removed
# - NaNs are removed during preprocessing
#
# Steps:
# 1. Iterate over all subjects
# 2. Compute time-frequency power
# 3. Cut baseline epochs and trial epochs
# 4. Baseline correct trial epochs
# 5.

# %% [markdown]
# ### Compute frequencies to use in logarithmic scale

# %%
import numpy as np

fmin = 2
fmax = 128
fnum = 30

np.logspace(np.log10(fmin), np.log10(fmax), fnum)

# %% [markdown]
# ### Center Frequencies and Number of Cycles for Complex Morelet Wavelet

# %%
import matplotlib.pyplot as plt
import numpy as np
import neuropsy.analysis as npsa


# ********* PARAMETERS ********* #
fs                          = 512
t_wl                        = np.arange(-4, 4+1/fs, 1/fs) # long enough time to capture the wavelet for given f and n
frequencies                 = np.arange(2, 32, 2)
cycles                      = np.insert(np.flipud(np.arange(3, 13, 1)), [-1, -2, -3, -4, -5], [3, 4, 5, 6, 7])

# ********* WAVELET AND PLOT ********* #
fig, ax = plt.subplots(figsize=(25, 15), nrows=4, ncols=4)#, sharex=True, sharey=True)
fig2, ax2 = plt.subplots(figsize=(25, 15), nrows=4, ncols=4)#, sharex=True, sharey=True)
ax = ax.flatten()
ax2 = ax2.flatten()

wavelet_funcs = {}
for i, (f, n) in enumerate(zip(frequencies, cycles)):

    # create complex Morlet wavelet
    wavelet, gauss_env = npsa.morlet(f, n, t_wl, return_gaussian=True)
    wavelet_funcs[f] = wavelet
    
    # plot wavelet and gaussian envelope
    ax[i].plot(t_wl, gauss_env, ':', label='envelope', color='black')
    ax[i].plot(t_wl, wavelet.real, label='real')
    ax[i].plot(t_wl, wavelet.imag, label='imaginary', linestyle='--', linewidth=1.)
    ax[i].set_title(f'f = {f}, cycles = {n}')
    if (i % 4 == 0) or (i % 8 == 0) or (i % 12 == 0) or (i % 16 == 0):
        ax[i].set_ylabel('Amplitude')
    if i == 0:
        ax[-1].set_xlabel('Time (s)')
        ax[-2].set_xlabel('Time (s)')
        ax[-3].set_xlabel('Time (s)')
        ax[-4].set_xlabel('Time (s)')
    ax[i].legend(loc='upper right', shadow=True)
    
    # plot frequency spectrum
    xf, y = npsa.compute_fft(wavelet, fs, output='mag')
    ax2[i].plot(xf, y)
    ax2[i].set_title(f'f = {f}, cycles = {n}')
    if (i % 4 == 0) or (i % 8 == 0) or (i % 12 == 0) or (i % 16 == 0):
        ax2[i].set_ylabel('Density')
    if i == 0:
        ax2[-1].set_xlabel('Frequency (Hz)')
        ax2[-2].set_xlabel('Frequency (Hz)')
        ax2[-3].set_xlabel('Frequency (Hz)')
        ax2[-4].set_xlabel('Frequency (Hz)')
    # ax2[i, j].set_yscale('log')
    ax2[i].set_xlim([-1, 40])
    # ax2[i, j].set_ylim([40, 120])
        
fig.suptitle('Complex Morlet wavelet - Time Domain', fontsize=16, y=.92)
fig2.suptitle('Complex Morlet wavelet - Frequency Domain', fontsize=16, y=.92)
plt.show()

# %% [markdown]
# ## 1. Time-frequency Representation (Manual Convolution)

# %%
import neuropsy as nps
import neuropsy.analysis as npsa
import numpy as np
import matplotlib.pyplot as plt
import time
import pickle
from scipy import signal
from scipy.fftpack import next_fast_len
# from scipy.fft import fft, fftfreq, ifft
# import pywt


#********** PARAMETERS **********#
path_data                   = '/mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/data/preprocessed'
path_save                   = '/mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis'
subject_ids                 = nps.utils.get_subject_ids_from_path(path_data)

# analysis parameters
conditions                  = ('uncertain', 'certain')
stimulus                    = 'Picture Placed'
tmin                        = -1
tmax                        = 1
baseline                    = (-1, -.5)
baseline_method             = 'mean'

# wavelet parameters
fs                          = 512
t_wl                        = np.arange(-4, 4+1/fs, 1/fs) # long enough time to capture the wavelet for given f and n
frequencies                 = np.arange(2, 32, 2)
cycles                      = np.insert(np.flipud(np.arange(3, 13, 1)), [-1, -2, -3, -4, -5], [3, 4, 5, 6, 7])
n_half_wavelet              = len(t_wl) // 2

# plot parameters
cmap                        = 'RdBu_r'


#********** START ANALYSIS **********#
dict_tfr_power_results = {}
for subject_id in subject_ids:
    start_time_sub = time.time()
    print(f"Starting subject {subject_id}...")
    
    dict_tfr_power_results[subject_id] = {}

    #********** LOAD SUBJECT DATA **********# 
    data = nps.DataHandler(path=path_data, subject_id=subject_id, exp_phase=2, fs=512, verbose=False)
    data.load(load_saved=True, postfix='preprocessed')
    
    # subtract total mean from each channel to remove DC bias
    total_mean = np.mean(data.ieeg)
    for i in range(data.ieeg.shape[0]):
        data.ieeg[i, :] = data.ieeg[i, :] - total_mean
        data.ieeg[i, :] = signal.detrend(data.ieeg[i, :])
        
    # select channels in hippocampus
    ch_names = data.df_chan[(data.df_chan['HC left'] == True) | (data.df_chan['HC right'] == True)]['name'].to_list()
    data.select_channels(ch_names=np.ravel(ch_names), inplace=True)


    #********** CREATE MNE RAW IN DATA OBJECT **********#
    data.create_raw()
    

    #********** GET TRIAL TIME POINTS (INDICES) **********#
    # need trial indices for "uncertain" and "certain" conditions from experiment dataframe
    # also need the corresponding trial indices for the baseline (picture shown)
    dict_trial_indices = {
        conditions[0]: [],
        f'{conditions[0]}_baseline': [],
        conditions[1]: [],
        f'{conditions[1]}_baseline': []
    }
    for condition in conditions:
        # get the trial indices for the condition
        idx_condition = data.df_exp[data.df_exp['Trial Category'] == condition][f'Mark for {stimulus}'].to_list()
        idx_baseline = data.df_exp[data.df_exp['Trial Category'] == condition]['Mark for Picture Shown'].to_list()
        # save indices
        dict_trial_indices[condition].append(idx_condition)
        dict_trial_indices[f"{condition}_baseline"].append(idx_baseline)
    # flatten lists
    for key in dict_trial_indices.keys():
        dict_trial_indices[key] = np.ravel(dict_trial_indices[key])


    #********** TIME-FREQUENCY ANALYSIS **********#
    # condition perhaps vary in trial number
    dict_tfr_power_results[subject_id] = {}
    for condition in conditions:
        start_time_cond = time.time()
        print(f"\tStarting condition {repr(condition)}...")
        
        dict_tfr_power_results[subject_id][condition] = {}
        
        for ch in ch_names:
            start_time_ch = time.time()
            
            # use the whole channel signal for computing time-frequency representation
            ch_signal = data.raw._data[ch_names.index(ch), ...]
            
            # ********* FFT of CHANNEL ********* #
            n_conv      = len(t_wl) + len(ch_signal) - 1
            n_conv_fast = next_fast_len(n_conv)
            signal_fft  = np.fft.fft(ch_signal, n_conv_fast)
            
            
            # initialise output data for continuous wavelet transform
            tf_data = np.zeros((len(frequencies), len(ch_signal)))

            # ********* CWT ********* #
            for i, (f, n) in enumerate(zip(frequencies, cycles)):
                
                print(f"creating wavelet with parameters: f = {f}, n = {n}...")
                
                # create wavelet
                wavelet = npsa.morlet(f, n, t_wl)
                
                # fft of wavelet
                # note:
                #   output must match the length of the signal_fft in order to multiply in the frequency domain
                wavelet_fft = np.fft.fft(wavelet, n=n_conv_fast)
                
                # convolution
                coefficients = np.fft.ifft(signal_fft * wavelet_fft, n=n_conv_fast)
                coefficients = coefficients[:n_conv] # remove padding from next_fast_len
                coefficients = coefficients[n_half_wavelet:-n_half_wavelet]
                
                # convert to power in dB
                tf_power = 10 * np.log10(np.abs(coefficients)**2)
                
                # store result for frequency
                tf_data[i, :] = tf_power
            
            # get baseline periods for all trials
            baseline_power = []
            for i in dict_trial_indices[f'{condition}_baseline']:
                # get baseline period for trial
                b_tmin = int(i + int(baseline[0] * fs))
                b_tmax = int(i + int(baseline[1] * fs))
                baseline_power.append(tf_data[:, b_tmin:b_tmax])
                
            # average baseline power
            baseline_power_avg = np.mean(baseline_power, axis=0)
            
            # get power for all trials
            power_trials = []
            for i in dict_trial_indices[condition]:
                # get power for trial
                t_tmin = int(i + int(tmin * fs))
                t_tmax = int(i + int(tmax * fs))
                power_trials.append(tf_data[:, t_tmin:t_tmax])
            
            # baseline correction
            power_trials_corrected = []
            for t_pow in power_trials:
                t_pow_corrected = npsa.apply_baseline(epoch_power=t_pow, baseline_power=baseline_power_avg, method=baseline_method)
                power_trials_corrected.append(t_pow_corrected)
                
            # store result for channel
            result = np.mean(power_trials_corrected, axis=0)
            dict_tfr_power_results[subject_id][condition][ch] = result
            
            # clean up
            # del signal, coefficients, baseline_power, baseline_power_avg, power_trials, power_trials_corrected
            print(f"\t\tChannel {ch} done - {time.time() - start_time_ch:.2f} seconds")
        print(f"\tCondition {repr(condition)} done - {time.time() - start_time_cond:.2f} seconds")
    print(f"Subject {subject_id} done - {time.time() - start_time_sub:.2f} seconds")
    
    #********** PLOT RESULTS **********#
    fig, ax = plt.subplots(nrows=2, ncols=len(ch_names), figsize=(25, 8))
    for i, condition in enumerate(conditions):
        for j, ch in enumerate(ch_names):
            
            im = ax[i, j].imshow(
                dict_tfr_power_results[subject_id][condition][ch], 
                aspect='auto',
                extent=[tmin, tmax, (frequencies)[0], (frequencies)[-1]],
                origin='lower', 
                vmin=-3,
                vmax=3,
                cmap=cmap,
                interpolation='hanning')
            ax[i, j].set_title(f'{condition} - {ch}', fontsize=12)
            ax[i, 0].set_ylabel('Frequency (Hz)', fontsize=10)      # only set ylabel for left most plots
            ax[1, j].set_xlabel('Time (s)', fontsize=10)            # only set xlabel for bottom plots
            ax[i, j].axvline(x=0, color='black', linestyle='--', linewidth=1.)
            ax[i, j].set_yscale('log')                              # show frequency in log scale
            ax[i, j].set_yticks([2, 10, 20, 30], [2, 10, 20, 30])
            if i == len(conditions) - 1 and j == len(ch_names) - 1:
                cbar = fig.colorbar(im, ax=ax.ravel().tolist(), shrink=0.90, pad=0.01, orientation="vertical")
                cbar.ax.set_ylabel("dB change from baseline", rotation=270, labelpad=15, fontsize=12)

    fig.suptitle(f"Subject {data._subject_id}", fontsize=18, y=0.95, x=.45)
    
    print(f"Saving plot for subject {subject_id}...")
    full_save_path = f"{path_save}/manual/sub{data._subject_id}_power_chan.png"
    fig.savefig(full_save_path, dpi=300, bbox_inches='tight')
    print(f"Done - {full_save_path}")
    plt.close(fig)
    # plt.show()
        
    # break
        

#********** SAVE RESULTS **********#
filename = f"{path_save}/data/tfr_power_results_manual.pkl"
with open(filename, 'wb') as f:
    print("Saving results...")
    pickle.dump(dict_tfr_power_results, f)
    print("Done")
# Out:
# Starting subject 03...
# Creating RawArray with float64 data, n_channels=5, n_times=823114
#     Range : 0 ... 823113 =      0.000 ...  1607.643 secs
# Ready.
# 	Starting condition 'uncertain'...
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 02 done - 0.86 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 03 done - 0.84 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 04 done - 0.95 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 05 done - 0.87 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C' 02 done - 0.87 seconds
# 	Condition 'uncertain' done - 4.40 seconds
# 	Starting condition 'certain'...
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 02 done - 0.87 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 03 done - 0.84 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 04 done - 0.88 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 05 done - 0.87 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C' 02 done - 0.87 seconds
# 	Condition 'certain' done - 4.33 seconds
# Subject 03 done - 15.95 seconds
# Saving plot for subject 03...
# Done - /mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis/manual/sub03_power_chan.png
# Starting subject 04...
# Creating RawArray with float64 data, n_channels=8, n_times=868110
#     Range : 0 ... 868109 =      0.000 ...  1695.525 secs
# Ready.
# 	Starting condition 'uncertain'...
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 02 done - 1.08 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 03 done - 1.00 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 04 done - 0.95 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C 02 done - 1.02 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C 03 done - 1.05 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C 04 done - 0.95 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 02 done - 0.92 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C' 02 done - 0.87 seconds
# 	Condition 'uncertain' done - 7.84 seconds
# 	Starting condition 'certain'...
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 02 done - 0.92 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 03 done - 0.87 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 04 done - 0.92 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C 02 done - 0.89 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C 03 done - 0.90 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C 04 done - 0.87 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 02 done - 0.99 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C' 02 done - 0.89 seconds
# 	Condition 'certain' done - 7.26 seconds
# Subject 04 done - 24.56 seconds
# Saving plot for subject 04...
# Done - /mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis/manual/sub04_power_chan.png
# Starting subject 05...
# Creating RawArray with float64 data, n_channels=9, n_times=427674
#     Range : 0 ... 427673 =      0.000 ...   835.299 secs
# Ready.
# 	Starting condition 'uncertain'...
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 02 done - 0.39 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 03 done - 0.37 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 04 done - 0.36 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 02 done - 0.37 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 03 done - 0.36 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 04 done - 0.39 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 05 done - 0.37 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C' 02 done - 0.38 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C' 03 done - 0.39 seconds
# 	Condition 'uncertain' done - 3.39 seconds
# 	Starting condition 'certain'...
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 02 done - 0.37 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 03 done - 0.38 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 04 done - 0.39 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 02 done - 0.36 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 03 done - 0.38 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 04 done - 0.37 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 05 done - 0.36 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C' 02 done - 0.38 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C' 03 done - 0.36 seconds
# 	Condition 'certain' done - 3.36 seconds
# Subject 05 done - 11.65 seconds
# Saving plot for subject 05...
# Done - /mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis/manual/sub05_power_chan.png
# Starting subject 07...
# Creating RawArray with float64 data, n_channels=7, n_times=1363811
#     Range : 0 ... 1363810 =      0.000 ...  2663.691 secs
# Ready.
# 	Starting condition 'uncertain'...
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 02 done - 1.50 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 03 done - 1.59 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 04 done - 1.52 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C 02 done - 1.52 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C 03 done - 1.52 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 02 done - 1.49 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 03 done - 1.57 seconds
# 	Condition 'uncertain' done - 10.71 seconds
# 	Starting condition 'certain'...
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 02 done - 1.52 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 03 done - 1.53 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 04 done - 1.50 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C 02 done - 1.54 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C 03 done - 1.50 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 02 done - 1.51 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# ...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C' 03 done - 0.86 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C' 04 done - 0.81 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel D' 02 done - 0.83 seconds
# 	Condition 'certain' done - 7.74 seconds
# Subject 15 done - 28.81 seconds
# Saving plot for subject 15...
# Done - /mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis/manual/sub15_power_chan.png
# Starting subject 19...
# Creating RawArray with float64 data, n_channels=8, n_times=1018626
#     Range : 0 ... 1018625 =      0.000 ...  1989.502 secs
# Ready.
# 	Starting condition 'uncertain'...
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 02 done - 1.14 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 03 done - 1.11 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 02 done - 1.07 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 03 done - 1.04 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 04 done - 1.03 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C' 02 done - 0.99 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C' 03 done - 1.07 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C' 04 done - 1.03 seconds
# 	Condition 'uncertain' done - 8.48 seconds
# 	Starting condition 'certain'...
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 02 done - 0.97 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B 03 done - 1.04 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 02 done - 1.00 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 03 done - 1.01 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel B' 04 done - 0.97 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C' 02 done - 0.99 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C' 03 done - 0.98 seconds
# creating wavelet with parameters: f = 2, n = 12...
# creating wavelet with parameters: f = 4, n = 11...
# creating wavelet with parameters: f = 6, n = 10...
# creating wavelet with parameters: f = 8, n = 9...
# creating wavelet with parameters: f = 10, n = 8...
# creating wavelet with parameters: f = 12, n = 7...
# creating wavelet with parameters: f = 14, n = 7...
# creating wavelet with parameters: f = 16, n = 6...
# creating wavelet with parameters: f = 18, n = 6...
# creating wavelet with parameters: f = 20, n = 5...
# creating wavelet with parameters: f = 22, n = 5...
# creating wavelet with parameters: f = 24, n = 4...
# creating wavelet with parameters: f = 26, n = 4...
# creating wavelet with parameters: f = 28, n = 3...
# creating wavelet with parameters: f = 30, n = 3...
# 		Channel C' 04 done - 1.02 seconds
# 	Condition 'certain' done - 7.98 seconds
# Subject 19 done - 32.78 seconds
# Saving plot for subject 19...
# Done - /mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis/manual/sub19_power_chan.png
# Saving results...
# Done

# %% [markdown]
# ### 1.1 Average Conditions

# %%
import pickle

path_save   = '/mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis'
filename    = f"{path_save}/data/tfr_power_results_manual.pkl"
conditions  = ('uncertain', 'certain')

# load previously computed time-frequency power for all subjects
with open(filename, 'rb') as f:
    power_data = pickle.load(f)
# power_data = dict_tfr_power_results

#********** AVERAGE ALL CHANNELS PER CONDITION **********#
power_averaged = {}
for condition in conditions:
    print(f"condition: {repr(condition)}")
    power_averaged[condition] = []
    
    for subject_id in power_data.keys():
        for channel in power_data[subject_id][condition].keys():
            # save channel data
            power_averaged[condition].append(power_data[subject_id][condition].get(channel))
    
    print("Shape before average:")
    print(f"\t{np.array(power_averaged[condition]).shape}")
    # compute mean of all channels across subjects for condition
    power_averaged[condition] = np.mean(power_averaged[condition], axis=0)
    
    print("Shape after average:")
    print(f"\t{np.array(power_averaged[condition]).shape}\n")
    

#********** PLOT RESULTS **********#
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
ax = ax.flatten()
for i, condition in enumerate(conditions):
        
        im = ax[i].imshow(
            power_averaged[condition], 
            aspect='auto',
            extent=[tmin, tmax, (frequencies)[0], (frequencies)[-1]],
            origin='lower', 
            vmin=-1,
            vmax=1,
            cmap=cmap,
            interpolation='hanning')
        ax[i].set_title(f'{condition}', fontsize=16)
        ax[i].set_ylabel('Frequency (Hz)', fontsize=10)      # only set ylabel for left most plots
        ax[i].set_xlabel('Time (s)', fontsize=10)            # only set xlabel for bottom plots
        ax[i].axvline(x=0, color='black', linestyle='--', linewidth=1.)
        ax[i].set_yscale('log')                              # show frequency in log scale
        ax[i].set_yticks([2, 10, 20, 30], [2, 10, 20, 30])
        if i == 1:
            cbar = fig.colorbar(im, ax=ax.ravel().tolist(), shrink=0.90, pad=0.01, orientation="vertical")
            cbar.ax.set_ylabel("dB change from baseline", rotation=270, labelpad=15, fontsize=12)

fig.suptitle(f"Condition Average", fontsize=18, y=0.99, x=.45)

full_save_path = f"{path_save}/manual/conditions_power_avg.png"
fig.savefig(full_save_path, dpi=300, bbox_inches='tight')
plt.show()
# Out:
# condition: 'uncertain'
# Shape before average:
# 	(70, 15, 1024)
# Shape after average:
# 	(15, 1024)
#
# condition: 'certain'
# Shape before average:
# 	(70, 15, 1024)
# Shape after average:
# 	(15, 1024)

# %% [markdown]
# ### 1.2 Total Average

# %%
import pickle

path_save   = '/mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis'
filename    = f"{path_save}/data/tfr_power_results_manual.pkl"
conditions  = ('uncertain', 'certain')

# load previously computed time-frequency power for all subjects
with open(filename, 'rb') as f:
    power_data = pickle.load(f)

#********** AVERAGE ALL CHANNELS **********#
power_averaged = []
for condition in conditions:
    print(f"condition: {repr(condition)}")
    
    for subject_id in power_data.keys():
        for channel in power_data[subject_id][condition].keys():
            # save channel data
            power_averaged.append(power_data[subject_id][condition].get(channel))
    
print("Shape before average:")
print(f"\t{np.array(power_averaged).shape}")
# compute mean of all channels across subjects
power_averaged = np.mean(power_averaged, axis=0)

print("Shape after average:")
print(f"\t{np.array(power_averaged).shape}\n")
    

#********** PLOT RESULTS **********#
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 5))
        
im = ax.imshow(
    power_averaged, 
    aspect='auto',
    extent=[tmin, tmax, (frequencies)[0], (frequencies)[-1]],
    origin='lower', 
    vmin=-1,
    vmax=1,
    cmap=cmap)
ax.set_title('Total Average', fontsize=18)
ax.set_ylabel('Frequency (Hz)', fontsize=10)      # only set ylabel for left most plots
ax.set_xlabel('Time (s)', fontsize=10)            # only set xlabel for bottom plots
ax.axvline(x=0, color='black', linestyle='--', linewidth=1.)
ax.set_yscale('log')                              # show frequency in log scale
ax.set_yticks([2, 10, 20, 30], [2, 10, 20, 30])
if i == 1:
    cbar = fig.colorbar(im, ax=ax, shrink=0.90, pad=0.01, orientation="vertical")
    cbar.ax.set_ylabel("dB change from baseline", rotation=270, labelpad=15, fontsize=12)

# fig.suptitle(f"Total Average", fontsize=18, y=0.99, x=.45)

full_save_path = f"{path_save}/manual/total_power_avg.png"
fig.savefig(full_save_path, dpi=300, bbox_inches='tight')
plt.show()
# Out:
# condition: 'uncertain'
# condition: 'certain'
# Shape before average:
# 	(140, 15, 1024)
# Shape after average:
# 	(15, 1024)

# %% [markdown]
# ### 1.3 Condition Difference

# %%
import pickle

path_save   = '/mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis'
filename    = f"{path_save}/data/tfr_power_results_manual.pkl"
conditions  = ('uncertain', 'certain')

# load previously computed time-frequency power for all subjects
with open(filename, 'rb') as f:
    power_data = pickle.load(f)

#********** AVERAGE ALL CHANNELS PER CONDITION **********#
power_averaged = {}
for condition in conditions:
    print(f"condition: {repr(condition)}")
    power_averaged[condition] = []
    
    for subject_id in power_data.keys():
        for channel in power_data[subject_id][condition].keys():
            # save channel data
            power_averaged[condition].append(power_data[subject_id][condition].get(channel))
    
    print("Shape before average:")
    print(f"\t{np.array(power_averaged[condition]).shape}")
    # compute mean of all channels across subjects for condition
    power_averaged[condition] = np.mean(power_averaged[condition], axis=0)
    
    print("Shape after average:")
    print(f"\t{np.array(power_averaged[condition]).shape}\n")
    

#********** SUBSTRACT CONDITION AVERAGE TO GET DIFFERENCE **********#
power_diff = power_averaged[conditions[0]] - power_averaged[conditions[1]]
    

#********** PLOT RESULTS **********#
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 5))
        
im = ax.imshow(
    power_diff, 
    aspect='auto',
    extent=[tmin, tmax, (frequencies)[0], (frequencies)[-1]],
    origin='lower', 
    vmin=-.5,
    vmax=.5,
    cmap=cmap)
ax.set_title(f"{conditions[0]} - {conditions[1]}", fontsize=18)
ax.set_ylabel('Frequency (Hz)', fontsize=10)      # only set ylabel for left most plots
ax.set_xlabel('Time (s)', fontsize=10)            # only set xlabel for bottom plots
ax.axvline(x=0, color='black', linestyle='--', linewidth=1.)
ax.set_yscale('log')                              # show frequency in log scale
ax.set_yticks([2, 10, 20, 30], [2, 10, 20, 30])
if i == 1:
    cbar = fig.colorbar(im, ax=ax, shrink=0.90, pad=0.01, orientation="vertical")
    cbar.ax.set_ylabel("dB difference", rotation=270, labelpad=15, fontsize=12)

# fig.suptitle(f"Total Average", fontsize=18, y=0.99, x=.45)

full_save_path = f"{path_save}/manual/condition_power_diff.png"
fig.savefig(full_save_path, dpi=300, bbox_inches='tight')
plt.show()
# Out:
# condition: 'uncertain'
# Shape before average:
# 	(70, 15, 1024)
# Shape after average:
# 	(15, 1024)
#
# condition: 'certain'
# Shape before average:
# 	(70, 15, 1024)
# Shape after average:
# 	(15, 1024)

# %% [markdown]
# ## 2. Time-frequency Representation (Using PyWavelets Library)

# %%
import neuropsy as nps
import neuropsy.analysis as npsa
import numpy as np
import pywt
import matplotlib.pyplot as plt
import time
import pickle

#********** PARAMETERS **********#
path_data                   = '/mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/data/preprocessed'
path_save                   = '/mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis'
subject_ids                 = nps.utils.get_subject_ids_from_path(path_data)

# analysis parameters
conditions                  = ('uncertain', 'certain')
stimulus                    = 'Picture Placed'
tmin                        = -1
tmax                        = 1
baseline                    = (-1, -.5)
baseline_method             = 'mean'

# wavelet parameters
fs                          = 512
dt                          = 1/fs
freqs                       = np.arange(2, 32, 2)
bandwidth                   = 1.5
center_frequency            = 2.0
wavelet                     = pywt.ContinuousWavelet(f'cmor{bandwidth}-{center_frequency}') # complex morlet
# wavelet                 = f'cmor{bandwidth}-{center_frequency}' # complex morlet
scales                      = npsa.get_scales(freqs=freqs, wavelet=wavelet, fs=fs)

# plot parameters
cmap                        = 'RdBu_r'


#********** START ANALYSIS **********#
dict_tfr_power_results = {}
for subject_id in subject_ids:
    start_time_sub = time.time()
    print(f"Starting subject {subject_id}...")
    
    dict_tfr_power_results[subject_id] = {}

    #********** LOAD SUBJECT DATA **********# 
    data = nps.DataHandler(path=path_data, subject_id=subject_id, exp_phase=2, fs=512, verbose=False)
    data.load(load_saved=True, postfix='preprocessed')

    # select channels in hippocampus
    ch_names = data.df_chan[(data.df_chan['HC left'] == True) | (data.df_chan['HC right'] == True)]['name'].to_list()
    data.select_channels(ch_names=np.ravel(ch_names), inplace=True)


    #********** CREATE MNE RAW IN DATA OBJECT **********#
    data.create_raw()
    

    #********** GET TRIAL TIME POINTS (INDICES) **********#
    # need trial indices for "uncertain" and "certain" conditions from experiment dataframe
    # also need the corresponding trial indices for the baseline (picture shown)
    dict_trial_indices = {
        conditions[0]: [],
        f'{conditions[0]}_baseline': [],
        conditions[1]: [],
        f'{conditions[1]}_baseline': []
    }
    for condition in conditions:
        # get the trial indices for the condition
        idx_condition = data.df_exp[data.df_exp['Trial Category'] == condition][f'Mark for {stimulus}'].to_list()
        idx_baseline = data.df_exp[data.df_exp['Trial Category'] == condition]['Mark for Picture Shown'].to_list()
        # save indices
        dict_trial_indices[condition].append(idx_condition)
        dict_trial_indices[f"{condition}_baseline"].append(idx_baseline)
    # flatten lists
    for key in dict_trial_indices.keys():
        dict_trial_indices[key] = np.ravel(dict_trial_indices[key])


    #********** TIME-FREQUENCY ANALYSIS **********#
    # condition perhaps vary in trial number
    dict_tfr_power_results[subject_id] = {}
    for condition in conditions:
        start_time_cond = time.time()
        print(f"\tStarting condition {repr(condition)}...")
        
        dict_tfr_power_results[subject_id][condition] = {}
        
        for ch in ch_names:
            start_time_ch = time.time()
            
            # use the whole channel signal for computing time-frequency representation
            signal = data.raw._data[ch_names.index(ch), ...]
            
            # compute time-frequency representation
            [coefficients, frequencies]     = pywt.cwt(data=signal, scales=scales, wavelet=wavelet, sampling_period=dt)
            # extract amplitude (magnitude of complex number is amplitude)
            amplitude                       = np.abs(coefficients)
            # convert to power (the amplitude squared gives the power)
            power_all                       = amplitude ** 2
            # scale power to log10
            power_all                       = 10 * np.log10(power_all)
            
            # get baseline periods for all trials
            baseline_power = []
            for i in dict_trial_indices[f'{condition}_baseline']:
                # get baseline period for trial
                b_tmin = int(i + int(baseline[0] * fs))
                b_tmax = int(i + int(baseline[1] * fs))
                baseline_power.append(power_all[:, b_tmin:b_tmax])
                
            # average baseline power
            baseline_power_avg = np.mean(baseline_power, axis=0)
            
            # get power for all trials
            power_trials = []
            for i in dict_trial_indices[condition]:
                # get power for trial
                t_tmin = int(i + int(tmin * fs))
                t_tmax = int(i + int(tmax * fs))
                power_trials.append(power_all[:, t_tmin:t_tmax])
                
            # baseline correction
            power_trials_corrected = []
            for t_pow in power_trials:
                t_pow_corrected = npsa.apply_baseline(epoch_power=t_pow, baseline_power=baseline_power_avg, method=baseline_method)
                power_trials_corrected.append(t_pow_corrected)
            
            # average across trials and save result for channel
            dict_tfr_power_results[subject_id][condition][ch] = np.mean(power_trials_corrected, axis=0, dtype=np.float64)
            
            # clean up
            # del signal, coefficients, amplitude, power_all, baseline_power, baseline_power_avg, power_trials, power_trials_corrected
            print(f"\t\tChannel {ch} done - {time.time() - start_time_ch:.2f} seconds")
        print(f"\tCondition {repr(condition)} done - {time.time() - start_time_cond:.2f} seconds")
    print(f"Subject {subject_id} done - {time.time() - start_time_sub:.2f} seconds")
    
    #********** PLOT RESULTS **********#
    fig, ax = plt.subplots(nrows=2, ncols=len(ch_names), figsize=(25, 8))
    for i, condition in enumerate(conditions):
        for j, ch in enumerate(ch_names):
            
            im = ax[i, j].imshow(
                dict_tfr_power_results[subject_id][condition][ch], 
                aspect='auto',
                extent=[tmin, tmax, (frequencies)[0], (frequencies)[-1]],
                origin='lower', 
                vmin=-3,
                vmax=3,
                cmap=cmap,
                interpolation='hanning')
            ax[i, j].set_title(f'{condition} - {ch}', fontsize=12)
            ax[i, 0].set_ylabel('Frequency (Hz)', fontsize=10)      # only set ylabel for left most plots
            ax[1, j].set_xlabel('Time (s)', fontsize=10)            # only set xlabel for bottom plots
            ax[i, j].axvline(x=0, color='black', linestyle='--', linewidth=1.)
            ax[i, j].set_yscale('log')                              # show frequency in log scale
            ax[i, j].set_yticks([2, 10, 20, 30], [2, 10, 20, 30])
            if i == len(conditions) - 1 and j == len(ch_names) - 1:
                cbar = fig.colorbar(im, ax=ax.ravel().tolist(), shrink=0.90, pad=0.01, orientation="vertical")
                cbar.ax.set_ylabel("dB change from baseline", rotation=270, labelpad=15, fontsize=12)

    fig.suptitle(f"Subject {data._subject_id}", fontsize=18, y=0.95, x=.45)
    
    print(f"Saving plot for subject {subject_id}...")
    full_save_path = f"{path_save}/pywt/sub{data._subject_id}_power_chan.png"
    fig.savefig(full_save_path, dpi=300, bbox_inches='tight')
    print(f"Done - {full_save_path}")
    plt.close(fig)
    
    # break

#********** SAVE RESULTS **********#
filename = f"{path_save}/data/tfr_power_results_pywt.pkl"
with open(filename, 'wb') as f:
    print("Saving results...")
    pickle.dump(dict_tfr_power_results, f)
    print("Done")
# Out:
# Starting subject 03...
# Creating RawArray with float64 data, n_channels=5, n_times=823114
#     Range : 0 ... 823113 =      0.000 ...  1607.643 secs
# Ready.
# 	Starting condition 'uncertain'...
# 		Channel B' 02 done - 12.59 seconds
# 		Channel B' 03 done - 12.46 seconds
# 		Channel B' 04 done - 12.57 seconds
# 		Channel B' 05 done - 12.35 seconds
# 		Channel C' 02 done - 12.43 seconds
# 	Condition 'uncertain' done - 62.40 seconds
# 	Starting condition 'certain'...
# 		Channel B' 02 done - 12.51 seconds
# 		Channel B' 03 done - 12.51 seconds
# 		Channel B' 04 done - 12.47 seconds
# 		Channel B' 05 done - 12.48 seconds
# 		Channel C' 02 done - 12.80 seconds
# 	Condition 'certain' done - 62.76 seconds
# Subject 03 done - 133.28 seconds
# Saving plot for subject 03...
# Done - /mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis/pywt/sub03_power_chan.png
# Starting subject 04...
# Creating RawArray with float64 data, n_channels=8, n_times=868110
#     Range : 0 ... 868109 =      0.000 ...  1695.525 secs
# Ready.
# 	Starting condition 'uncertain'...
# 		Channel B 02 done - 13.19 seconds
# 		Channel B 03 done - 13.13 seconds
# 		Channel B 04 done - 13.05 seconds
# 		Channel C 02 done - 13.18 seconds
# 		Channel C 03 done - 13.13 seconds
# 		Channel C 04 done - 13.12 seconds
# 		Channel B' 02 done - 13.13 seconds
# 		Channel C' 02 done - 13.16 seconds
# 	Condition 'uncertain' done - 105.10 seconds
# 	Starting condition 'certain'...
# 		Channel B 02 done - 13.12 seconds
# 		Channel B 03 done - 13.11 seconds
# 		Channel B 04 done - 13.13 seconds
# 		Channel C 02 done - 13.22 seconds
# 		Channel C 03 done - 13.09 seconds
# 		Channel C 04 done - 13.06 seconds
# 		Channel B' 02 done - 13.17 seconds
# 		Channel C' 02 done - 13.22 seconds
# 	Condition 'certain' done - 105.11 seconds
# Subject 04 done - 217.77 seconds
# Saving plot for subject 04...
# Done - /mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis/pywt/sub04_power_chan.png
# Starting subject 05...
# Creating RawArray with float64 data, n_channels=9, n_times=427674
#     Range : 0 ... 427673 =      0.000 ...   835.299 secs
# Ready.
# 	Starting condition 'uncertain'...
# 		Channel B 02 done - 6.61 seconds
# 		Channel B 03 done - 6.47 seconds
# 		Channel B 04 done - 6.41 seconds
# 		Channel B' 02 done - 6.47 seconds
# 		Channel B' 03 done - 6.45 seconds
# 		Channel B' 04 done - 6.47 seconds
# 		Channel B' 05 done - 6.41 seconds
# 		Channel C' 02 done - 6.48 seconds
# 		Channel C' 03 done - 6.46 seconds
# 	Condition 'uncertain' done - 58.22 seconds
# 	Starting condition 'certain'...
# 		Channel B 02 done - 6.44 seconds
# 		Channel B 03 done - 6.49 seconds
# 		Channel B 04 done - 6.48 seconds
# 		Channel B' 02 done - 6.50 seconds
# 		Channel B' 03 done - 6.50 seconds
# 		Channel B' 04 done - 6.43 seconds
# 		Channel B' 05 done - 6.47 seconds
# 		Channel C' 02 done - 6.50 seconds
# 		Channel C' 03 done - 6.46 seconds
# 	Condition 'certain' done - 58.25 seconds
# Subject 05 done - 119.96 seconds
# Saving plot for subject 05...
# Done - /mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis/pywt/sub05_power_chan.png
# Starting subject 07...
# Creating RawArray with float64 data, n_channels=7, n_times=1363811
#     Range : 0 ... 1363810 =      0.000 ...  2663.691 secs
# Ready.
# 	Starting condition 'uncertain'...
# 		Channel B 02 done - 20.69 seconds
# 		Channel B 03 done - 20.78 seconds
# 		Channel B 04 done - 20.77 seconds
# 		Channel C 02 done - 20.88 seconds
# 		Channel C 03 done - 20.80 seconds
# 		Channel B' 02 done - 20.69 seconds
# 		Channel B' 03 done - 20.58 seconds
# 	Condition 'uncertain' done - 145.20 seconds
# 	Starting condition 'certain'...
# 		Channel B 02 done - 20.68 seconds
# 		Channel B 03 done - 20.88 seconds
# 		Channel B 04 done - 20.87 seconds
# 		Channel C 02 done - 20.61 seconds
# 		Channel C 03 done - 20.77 seconds
# 		Channel B' 02 done - 20.88 seconds
# 		Channel B' 03 done - 20.66 seconds
# 	Condition 'certain' done - 145.35 seconds
# Subject 07 done - 306.01 seconds
# Saving plot for subject 07...
# Done - /mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis/pywt/sub07_power_chan.png
# Starting subject 09...
# Creating RawArray with float64 data, n_channels=5, n_times=1383831
#     Range : 0 ... 1383830 =      0.000 ...  2702.793 secs
# Ready.
# 	Starting condition 'uncertain'...
# 		Channel B' 02 done - 21.25 seconds
# 		Channel B' 03 done - 21.26 seconds
# 		Channel B' 04 done - 21.06 seconds
# 		Channel B' 05 done - 21.00 seconds
# 		Channel C' 02 done - 21.07 seconds
# 	Condition 'uncertain' done - 105.64 seconds
# 	Starting condition 'certain'...
# 		Channel B' 02 done - 20.96 seconds
# 		Channel B' 03 done - 20.97 seconds
# 		Channel B' 04 done - 20.96 seconds
# 		Channel B' 05 done - 20.91 seconds
# 		Channel C' 02 done - 20.89 seconds
# 	Condition 'certain' done - 104.70 seconds
# Subject 09 done - 228.22 seconds
# Saving plot for subject 09...
# Done - /mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis/pywt/sub09_power_chan.png
# Starting subject 10...
# Creating RawArray with float64 data, n_channels=7, n_times=708398
#     Range : 0 ... 708397 =      0.000 ...  1383.588 secs
# Ready.
# 	Starting condition 'uncertain'...
# 		Channel B' 02 done - 10.81 seconds
# 		Channel B' 03 done - 10.86 seconds
# 		Channel B' 04 done - 10.68 seconds
# 		Channel C' 02 done - 10.67 seconds
# 		Channel C' 03 done - 10.68 seconds
# 		Channel C' 04 done - 10.76 seconds
# 		Channel C' 05 done - 10.75 seconds
# 	Condition 'uncertain' done - 75.19 seconds
# 	Starting condition 'certain'...
# 		Channel B' 02 done - 10.69 seconds
# 		Channel B' 03 done - 10.66 seconds
# 		Channel B' 04 done - 10.65 seconds
# 		Channel C' 02 done - 10.75 seconds
# 		Channel C' 03 done - 10.67 seconds
# 		Channel C' 04 done - 10.63 seconds
# 		Channel C' 05 done - 10.69 seconds
# 	Condition 'certain' done - 74.75 seconds
# Subject 10 done - 158.01 seconds
# Saving plot for subject 10...
# Done - /mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis/pywt/sub10_power_chan.png
# Starting subject 11...
# Creating RawArray with float64 data, n_channels=2, n_times=1081288
#     Range : 0 ... 1081287 =      0.000 ...  2111.889 secs
# Ready.
# 	Starting condition 'uncertain'...
# 		Channel Z 02 done - 16.75 seconds
# 		Channel Z 03 done - 16.79 seconds
# 	Condition 'uncertain' done - 33.54 seconds
# 	Starting condition 'certain'...
# 		Channel Z 02 done - 16.44 seconds
# 		Channel Z 03 done - 16.31 seconds
# 	Condition 'certain' done - 32.75 seconds
# Subject 11 done - 78.43 seconds
# Saving plot for subject 11...
# Done - /mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis/pywt/sub11_power_chan.png
# Starting subject 12...
# Creating RawArray with float64 data, n_channels=6, n_times=998554
#     Range : 0 ... 998553 =      0.000 ...  1950.299 secs
# Ready.
# 	Starting condition 'uncertain'...
# 		Channel B' 02 done - 15.14 seconds
# 		Channel B' 03 done - 15.17 seconds
# 		Channel B' 04 done - 15.10 seconds
# 		Channel E' 02 done - 15.05 seconds
# 		Channel E' 03 done - 15.10 seconds
# 		Channel E' 04 done - 15.18 seconds
# 	Condition 'uncertain' done - 90.73 seconds
# 	Starting condition 'certain'...
# 		Channel B' 02 done - 15.19 seconds
# 		Channel B' 03 done - 15.09 seconds
# 		Channel B' 04 done - 15.24 seconds
# 		Channel E' 02 done - 15.10 seconds
# 		Channel E' 03 done - 15.17 seconds
# 		Channel E' 04 done - 15.13 seconds
# 	Condition 'certain' done - 90.92 seconds
# Subject 12 done - 192.01 seconds
# Saving plot for subject 12...
# Done - /mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis/pywt/sub12_power_chan.png
# Starting subject 14...
# Creating RawArray with float64 data, n_channels=4, n_times=647222
#     Range : 0 ... 647221 =      0.000 ...  1264.104 secs
# Ready.
# 	Starting condition 'uncertain'...
# 		Channel B' 02 done - 9.92 seconds
# 		Channel B' 03 done - 9.80 seconds
# 		Channel C' 02 done - 9.75 seconds
# 		Channel C' 03 done - 9.86 seconds
# 	Condition 'uncertain' done - 39.34 seconds
# 	Starting condition 'certain'...
# 		Channel B' 02 done - 9.80 seconds
# 		Channel B' 03 done - 9.98 seconds
# 		Channel C' 02 done - 9.81 seconds
# 		Channel C' 03 done - 9.87 seconds
# 	Condition 'certain' done - 39.46 seconds
# Subject 14 done - 85.33 seconds
# Saving plot for subject 14...
# Done - /mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis/pywt/sub14_power_chan.png
# Starting subject 15...
# Creating RawArray with float64 data, n_channels=9, n_times=845938
#     Range : 0 ... 845937 =      0.000 ...  1652.221 secs
# Ready.
# 	Starting condition 'uncertain'...
# 		Channel B' 02 done - 13.01 seconds
# 		Channel B' 03 done - 12.96 seconds
# 		Channel B' 04 done - 12.97 seconds
# 		Channel B' 05 done - 12.77 seconds
# 		Channel B' 06 done - 12.91 seconds
# 		Channel C' 02 done - 12.79 seconds
# 		Channel C' 03 done - 12.74 seconds
# 		Channel C' 04 done - 12.77 seconds
# 		Channel D' 02 done - 12.81 seconds
# 	Condition 'uncertain' done - 115.72 seconds
# 	Starting condition 'certain'...
# 		Channel B' 02 done - 12.93 seconds
# 		Channel B' 03 done - 12.84 seconds
# 		Channel B' 04 done - 12.95 seconds
# 		Channel B' 05 done - 12.85 seconds
# 		Channel B' 06 done - 12.87 seconds
# 		Channel C' 02 done - 13.04 seconds
# 		Channel C' 03 done - 12.85 seconds
# 		Channel C' 04 done - 13.08 seconds
# 		Channel D' 02 done - 12.80 seconds
# 	Condition 'certain' done - 116.23 seconds
# Subject 15 done - 242.58 seconds
# Saving plot for subject 15...
# Done - /mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis/pywt/sub15_power_chan.png
# Starting subject 19...
# Creating RawArray with float64 data, n_channels=8, n_times=1018626
#     Range : 0 ... 1018625 =      0.000 ...  1989.502 secs
# Ready.
# 	Starting condition 'uncertain'...
# 		Channel B 02 done - 15.69 seconds
# 		Channel B 03 done - 15.66 seconds
# 		Channel B' 02 done - 15.27 seconds
# 		Channel B' 03 done - 15.52 seconds
# 		Channel B' 04 done - 15.43 seconds
# 		Channel C' 02 done - 15.42 seconds
# 		Channel C' 03 done - 15.55 seconds
# 		Channel C' 04 done - 15.28 seconds
# 	Condition 'uncertain' done - 123.82 seconds
# 	Starting condition 'certain'...
# 		Channel B 02 done - 15.42 seconds
# 		Channel B 03 done - 15.53 seconds
# 		Channel B' 02 done - 15.42 seconds
# 		Channel B' 03 done - 15.48 seconds
# 		Channel B' 04 done - 15.59 seconds
# 		Channel C' 02 done - 15.51 seconds
# 		Channel C' 03 done - 15.38 seconds
# 		Channel C' 04 done - 15.39 seconds
# 	Condition 'certain' done - 123.73 seconds
# Subject 19 done - 258.38 seconds
# Saving plot for subject 19...
# Done - /mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis/pywt/sub19_power_chan.png
# Saving results...
# Done

# %% [markdown]
# ### 2.1 Average Conditions

# %%
import pickle

path_save   = '/mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis'
filename    = f"{path_save}/data/tfr_power_results_pywt.pkl"
conditions  = ('uncertain', 'certain')

# load previously computed time-frequency power for all subjects
with open(filename, 'rb') as f:
    power_data = pickle.load(f)
# power_data = dict_tfr_power_results

#********** AVERAGE ALL CHANNELS PER CONDITION **********#
power_averaged = {}
for condition in conditions:
    print(f"condition: {repr(condition)}")
    power_averaged[condition] = []
    
    for subject_id in power_data.keys():
        for channel in power_data[subject_id][condition].keys():
            # save channel data
            power_averaged[condition].append(power_data[subject_id][condition].get(channel))
    
    print("Shape before average:")
    print(f"\t{np.array(power_averaged[condition]).shape}")
    # compute mean of all channels across subjects for condition
    power_averaged[condition] = np.mean(power_averaged[condition], axis=0)
    
    print("Shape after average:")
    print(f"\t{np.array(power_averaged[condition]).shape}\n")
    

#********** PLOT RESULTS **********#
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
ax = ax.flatten()
for i, condition in enumerate(conditions):
        
        im = ax[i].imshow(
            power_averaged[condition], 
            aspect='auto',
            extent=[tmin, tmax, (frequencies)[0], (frequencies)[-1]],
            origin='lower', 
            vmin=-1,
            vmax=1,
            cmap=cmap,
            interpolation='hanning')
        ax[i].set_title(f'{condition}', fontsize=16)
        ax[i].set_ylabel('Frequency (Hz)', fontsize=10)      # only set ylabel for left most plots
        ax[i].set_xlabel('Time (s)', fontsize=10)            # only set xlabel for bottom plots
        ax[i].axvline(x=0, color='black', linestyle='--', linewidth=1.)
        ax[i].set_yscale('log')                              # show frequency in log scale
        ax[i].set_yticks([2, 10, 20, 30], [2, 10, 20, 30])
        if i == 1:
            cbar = fig.colorbar(im, ax=ax.ravel().tolist(), shrink=0.90, pad=0.01, orientation="vertical")
            cbar.ax.set_ylabel("dB change from baseline", rotation=270, labelpad=15, fontsize=12)

fig.suptitle(f"Condition Average", fontsize=18, y=0.99, x=.45)

full_save_path = f"{path_save}/pywt/conditions_power_avg.png"
fig.savefig(full_save_path, dpi=300, bbox_inches='tight')
plt.show()
# Out:
# condition: 'uncertain'
# Shape before average:
# 	(70, 15, 1024)
# Shape after average:
# 	(15, 1024)
#
# condition: 'certain'
# Shape before average:
# 	(70, 15, 1024)
# Shape after average:
# 	(15, 1024)

# %% [markdown]
# ### 2.2 Total Average

# %%
import pickle

path_save   = '/mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis'
filename    = f"{path_save}/data/tfr_power_results_pywt.pkl"
conditions  = ('uncertain', 'certain')

# load previously computed time-frequency power for all subjects
with open(filename, 'rb') as f:
    power_data = pickle.load(f)

#********** AVERAGE ALL CHANNELS **********#
power_averaged = []
for condition in conditions:
    print(f"condition: {repr(condition)}")
    
    for subject_id in power_data.keys():
        for channel in power_data[subject_id][condition].keys():
            # save channel data
            power_averaged.append(power_data[subject_id][condition].get(channel))
    
print("Shape before average:")
print(f"\t{np.array(power_averaged).shape}")
# compute mean of all channels across subjects
power_averaged = np.mean(power_averaged, axis=0)

print("Shape after average:")
print(f"\t{np.array(power_averaged).shape}\n")
    

#********** PLOT RESULTS **********#
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 5))
        
im = ax.imshow(
    power_averaged, 
    aspect='auto',
    extent=[tmin, tmax, (frequencies)[0], (frequencies)[-1]],
    origin='lower', 
    vmin=-1,
    vmax=1,
    cmap=cmap)
ax.set_title('Total Average', fontsize=18)
ax.set_ylabel('Frequency (Hz)', fontsize=10)      # only set ylabel for left most plots
ax.set_xlabel('Time (s)', fontsize=10)            # only set xlabel for bottom plots
ax.axvline(x=0, color='black', linestyle='--', linewidth=1.)
ax.set_yscale('log')                              # show frequency in log scale
ax.set_yticks([2, 10, 20, 30], [2, 10, 20, 30])
if i == 1:
    cbar = fig.colorbar(im, ax=ax, shrink=0.90, pad=0.01, orientation="vertical")
    cbar.ax.set_ylabel("dB change from baseline", rotation=270, labelpad=15, fontsize=12)

# fig.suptitle(f"Total Average", fontsize=18, y=0.99, x=.45)

full_save_path = f"{path_save}/pywt/total_power_avg.png"
fig.savefig(full_save_path, dpi=300, bbox_inches='tight')
plt.show()
# Out:
# condition: 'uncertain'
# condition: 'certain'
# Shape before average:
# 	(140, 15, 1024)
# Shape after average:
# 	(15, 1024)

# %% [markdown]
# ### 2.3 Condition Difference

# %%
import pickle

path_save   = '/mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis'
filename    = f"{path_save}/data/tfr_power_results_pywt.pkl"
conditions  = ('uncertain', 'certain')

# load previously computed time-frequency power for all subjects
with open(filename, 'rb') as f:
    power_data = pickle.load(f)

#********** AVERAGE ALL CHANNELS PER CONDITION **********#
power_averaged = {}
for condition in conditions:
    print(f"condition: {repr(condition)}")
    power_averaged[condition] = []
    
    for subject_id in power_data.keys():
        for channel in power_data[subject_id][condition].keys():
            # save channel data
            power_averaged[condition].append(power_data[subject_id][condition].get(channel))
    
    print("Shape before average:")
    print(f"\t{np.array(power_averaged[condition]).shape}")
    # compute mean of all channels across subjects for condition
    power_averaged[condition] = np.mean(power_averaged[condition], axis=0)
    
    print("Shape after average:")
    print(f"\t{np.array(power_averaged[condition]).shape}\n")
    

#********** SUBSTRACT CONDITION AVERAGE TO GET DIFFERENCE **********#
power_diff = power_averaged[conditions[0]] - power_averaged[conditions[1]]
    

#********** PLOT RESULTS **********#
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 5))
        
im = ax.imshow(
    power_diff, 
    aspect='auto',
    extent=[tmin, tmax, (frequencies)[0], (frequencies)[-1]],
    origin='lower', 
    vmin=-.5,
    vmax=.5,
    cmap=cmap)
ax.set_title(f"{conditions[0]} - {conditions[1]}", fontsize=18)
ax.set_ylabel('Frequency (Hz)', fontsize=10)      # only set ylabel for left most plots
ax.set_xlabel('Time (s)', fontsize=10)            # only set xlabel for bottom plots
ax.axvline(x=0, color='black', linestyle='--', linewidth=1.)
ax.set_yscale('log')                              # show frequency in log scale
ax.set_yticks([2, 10, 20, 30], [2, 10, 20, 30])
if i == 1:
    cbar = fig.colorbar(im, ax=ax, shrink=0.90, pad=0.01, orientation="vertical")
    cbar.ax.set_ylabel("dB difference", rotation=270, labelpad=15, fontsize=12)

# fig.suptitle(f"Total Average", fontsize=18, y=0.99, x=.45)

full_save_path = f"{path_save}/pywt/condition_power_diff.png"
fig.savefig(full_save_path, dpi=300, bbox_inches='tight')
plt.show()
# Out:
# condition: 'uncertain'
# Shape before average:
# 	(70, 15, 1024)
# Shape after average:
# 	(15, 1024)
#
# condition: 'certain'
# Shape before average:
# 	(70, 15, 1024)
# Shape after average:
# 	(15, 1024)

# %% [markdown]
# ### (optional) Display Time-frequency Results for One Frequency

# %%
import pickle

path_save       = '/mnt/c/Users/matti/OneDrive/Education/SDC/Master Thesis/master-project/results/Research Question 1/Time-frequency Power Analysis'
filename_pywt   = f"{path_save}/data/tfr_power_results_pywt.pkl"
filename_man    = f"{path_save}/data/tfr_power_results_manual.pkl"
frequencies     = np.arange(2, 32, 2)

# load previously computed time-frequency power for all subjects
with open(filename_pywt, 'rb') as f:
    power_pywt = pickle.load(f)
with open(filename_man, 'rb') as f:
    power_man = pickle.load(f)


subject_id  = '03'
condition   = 'uncertain'
channel     = 'B\' 02'
frequency   = 1

plot_pywt   = power_pywt[str(subject_id)][condition][channel][frequency]
plot_man    = power_man[str(subject_id)][condition][channel][frequency]

fig, ax = plt.subplots(ncols=1, nrows=2, figsize=(15, 5))
ax = ax.flatten()

ax[0].plot(plot_pywt)
ax[0].set_title('PyWavelets')
ax[0].set_ylabel('Power (dB)')

ax[1].plot(plot_man)
ax[1].set_title('Manual')
ax[1].set_xlabel('Time (s)')
ax[1].set_ylabel('Power (dB)')

fig.suptitle(f"Subject {subject_id} - Channel {channel} - Condition {condition} - Frequency {frequencies[frequency]} Hz", fontsize=14, y=.98)
plt.tight_layout()
plt.show()
